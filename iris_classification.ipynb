# %% [markdown]
# # Iris Flower Classification

# %% [markdown]
# ### Data Loading & Basic Inspection

# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("iris.csv")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.shape
# Out:
# (150, 6)

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.sample(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 135  136            7.7           3.0            6.1           2.3
# 133  134            6.3           2.8            5.1           1.5
# 0      1            5.1           3.5            1.4           0.2
# 92    93            5.8           2.6            4.0           1.2
# 120  121            6.9           3.2            5.7           2.3
#
#              Species
# 135   Iris-virginica
# 133   Iris-virginica
# 0        Iris-setosa
# 92   Iris-versicolor
# 120   Iris-virginica

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# Id               150
# SepalLengthCm     35
# SepalWidthCm      23
# PetalLengthCm     43
# PetalWidthCm      22
# Species            3
# dtype: int64

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# ### Exploratory Data Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


df.columns = df.columns.str.strip().str.lower()  # normalize column names

print("Cleaned Columns:", df.columns.tolist())
assert 'species' in df.columns, "'species' column still not found!"
# Out:
# Cleaned Columns: ['id', 'sepallengthcm', 'sepalwidthcm', 'petallengthcm', 'petalwidthcm', 'species']

# %%
# Countplot
sns.countplot(x='species', data=df)
plt.title("Class Distribution")
plt.xlabel("Species")
plt.ylabel("Count")
plt.show()

# %%
# Boxplots
for col in df.columns[:-1]:
    sns.boxplot(x='species', y=col, data=df)
    plt.title(f'{col.capitalize()} by Species')
    plt.xlabel("Species")
    plt.ylabel(col.capitalize())
    plt.show()

# %%
# Histograms
df.hist(figsize=(10, 6), edgecolor='black', color='lightgreen')
plt.suptitle("Histograms of Features")
plt.tight_layout()
plt.show()

# %%
# Pairplot
sns.pairplot(df, hue='species')
plt.suptitle("Pairplot of Features by Species", y=1.02)
plt.show()

# %%
# Correlation Matrix
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Feature Correlation Matrix")
plt.show()

# %%
# Violin Plots
for col in df.columns[:-1]:
    sns.violinplot(x='species', y=col, data=df)
    plt.title(f'{col.capitalize()} Distribution by Species')
    plt.xlabel("Species")
    plt.ylabel(col.capitalize())
    plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import joblib

# %% [markdown]
# # Data Preprocessing

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
import joblib

# Load dataset
df = pd.read_csv('iris.csv')

# Drop 'Id' column, keep only feature columns
X = df.drop(['Id', 'Species'], axis=1)  # Keep only SepalLengthCm, SepalWidthCm, PetalLengthCm, PetalWidthCm
y = df['Species']

# Encode target labels
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# %% [markdown]
# # Train Machine Learning Models

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# Train Random Forest
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X_train, y_train)
print("Random Forest model trained.")

# Train SVM
svm_model = SVC(probability=True, random_state=42)
svm_model.fit(X_train, y_train)
# Out:
# Random Forest model trained.
# SVC(probability=True, random_state=42)

# %% [markdown]
# # Evaluate Both Models

# %%
joblib.dump(rf_model, 'iris_random_forest.pkl')
joblib.dump(svm_model, 'iris_svm.pkl')
joblib.dump(le, 'label_encoder.pkl')
# Out:
# ['label_encoder.pkl']

# %%
import pandas as pd
import joblib

# Load models and label encoder
rf_loaded = joblib.load('iris_random_forest.pkl')
svm_loaded = joblib.load('iris_svm.pkl')
le_loaded = joblib.load('label_encoder.pkl')

# Sample input - use the exact same feature column names
sample = pd.DataFrame([[5.9, 3.0, 5.1, 1.8]], 
                      columns=['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm'])

# Predict
rf_pred = rf_loaded.predict(sample)
svm_pred = svm_loaded.predict(sample)

# Decode predictions back to original labels
print("Random Forest predicts:", le_loaded.inverse_transform(rf_pred)[0])
print("SVM predicts:", le_loaded.inverse_transform(svm_pred)[0])
# Out:
# Random Forest predicts: Iris-virginica
# SVM predicts: Iris-virginica

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Predict on test set
y_pred_rf = rf_model.predict(X_test)
y_pred_svm = svm_model.predict(X_test)

# Accuracy
print(f"Random Forest Accuracy: {accuracy_score(y_test, y_pred_rf):.2f}")
print(f"SVM Accuracy: {accuracy_score(y_test, y_pred_svm):.2f}")

# Classification Reports
print("Random Forest Classification Report:")
print(classification_report(y_test, y_pred_rf, target_names=le.classes_))

print("SVM Classification Report:")
print(classification_report(y_test, y_pred_svm, target_names=le.classes_))

# Confusion Matrix Plots
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

cm_rf = confusion_matrix(y_test, y_pred_rf)
cm_svm = confusion_matrix(y_test, y_pred_svm)

sns.heatmap(cm_rf, annot=True, fmt='d', ax=axes[0], xticklabels=le.classes_, yticklabels=le.classes_, cmap='Blues')
axes[0].set_title('Random Forest Confusion Matrix')
axes[0].set_xlabel('Predicted')
axes[0].set_ylabel('Actual')

sns.heatmap(cm_svm, annot=True, fmt='d', ax=axes[1], xticklabels=le.classes_, yticklabels=le.classes_, cmap='Greens')
axes[1].set_title('SVM Confusion Matrix')
axes[1].set_xlabel('Predicted')
axes[1].set_ylabel('Actual')

plt.show()
# Out:
# Random Forest Accuracy: 1.00
# SVM Accuracy: 1.00
# Random Forest Classification Report:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        10
# Iris-versicolor       1.00      1.00      1.00         9
#  Iris-virginica       1.00      1.00      1.00        11
#
#        accuracy                           1.00        30
#       macro avg       1.00      1.00      1.00        30
#    weighted avg       1.00      1.00      1.00        30
#
# SVM Classification Report:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        10
# Iris-versicolor       1.00      1.00      1.00         9
#  Iris-virginica       1.00      1.00      1.00        11
#
#        accuracy                           1.00        30
#       macro avg       1.00      1.00      1.00        30
#    weighted avg       1.00      1.00      1.00        30
